# %%
import pandas as pd
import numpy as np
import spacy
import re
import joblib
import os
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

# %%
# lire le fichier des clusters
df_clusters = pd.read_csv("../clustering/dbscan_clustered_offres_new.csv")

# %%
df_clusters.head()
# Out:
#                                             titre    entreprise  \
# 0                  Téléconseillère commercial cdi             -
# 1              Commercial digital (h/f) à / bac+5            PJ
# 2                             Commercial showroom        TECTRA
# 3             Messagerie & transport / casablanca  Confidentiel
# 4  Commercial terrain rabat/ /kenitra et environs          Wafr
#
#                           secteur   localisation  \
# 0              Commercial / Vente     Mohammedia
# 1              Commercial / Vente     Casablanca
# 2              Commercial / Vente     Casablanca
# 3  Transport / Achat / Logistique  Tout le Maroc
# 4              Commercial / Vente           Salé
#
#                                          competences  \
# 0  bac+3 en gestions dadministration /commerce ou...
# 1                                              Vente
# 2  Modelisation 3D, SketchUp, AutoCAD, Relation c...
# 3                                         Logistique
# ...

# %%
len(df_clusters[df_clusters['cluster_dbscan'] == 33]['titre'])
# Out:
# 41

# %%
a = df_clusters[df_clusters['cluster_dbscan'] == 65]['text_clean'].reset_index()

# %%
len(df_clusters['cluster_dbscan'].value_counts())
# Out:
# 38

# %% [markdown]
# appliquation de sbscan
